# %% [markdown]
# ## Import packages

# %%
import gzip
import json
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from nltk.stem.snowball import stopwords
from datetime import datetime
from wordcloud import WordCloud
import string
import tensorflow as tf
from implicit import bpr
from surprise import SVD, Reader, Dataset
from surprise.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, r2_score
from collections import defaultdict
from sklearn.feature_extraction.text import CountVectorizer
sns.set()
sns.set_context('talk')

# %%
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        l = str(json.loads(l))
        yield eval(l)

# %% [markdown]
# ## Import dataset

# %%
# data_modcloth = []
# for l in parse("modcloth_final_data.json.gz"):
#     data_modcloth.append(l)

# %%
# data_modcloth[0]

# %%
data_renttherunway = []
for l in parse("renttherunway_final_data.json.gz"):
    data_renttherunway.append(l)

# %%
data_renttherunway[0]
# Out:
# {'fit': 'fit',
#  'user_id': '420272',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': '137lbs',
#  'rating': '10',
#  'rented for': 'vacation',
#  'review_text': "An adorable romper! Belt and zipper were a little hard to navigate in a full day of wear/bathroom use, but that's to be expected. Wish it had pockets, but other than that-- absolutely perfect! I got a million compliments.",
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': '5\' 8"',
#  'size': 14,
#  'age': '28',
#  'review_date': 'April 20, 2016'}

# %% [markdown]
# ## Data Clean

# %%
df = pd.DataFrame(data_renttherunway)

# %%
def standardize_height(str_in):
    if type(str_in) == float:
        return str_in
    str_in = str_in.strip()
    if '\'' in str_in:
        str_in = str_in.replace('\'', '')
    if '"' in str_in:
        str_in = str_in.replace('"', '')

    foot,inch = str_in.strip().split(' ')
    output = int(foot) * 12 + int(inch)

    return output

# %%
def standardize_weight(str_in):
    if type(str_in) == float:
        return str_in
    if 'lbs' in str_in:
        str_in = str_in.replace('lbs', '')
    if(str_in.isnumeric()):
        return int(str_in)

    return str_in

# %%
df.shape
# Out:
# (192544, 15)

# %%
# drop entries with null values
df = df.dropna() 
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (146381, 15)

# %%
rating_dict = {'2':1, '4':2, '6':3, '8':4, '10':5}

# %%
df['height'] = df['height'].apply(lambda x: standardize_height(x))
df['weight'] = df['weight'].apply(lambda x: standardize_weight(x))
df['age'] = df['age'].apply(lambda x: int(x))
df['fit_sml'] = df['fit'].apply(lambda x: 0 if x=='small' else 1 if x=='fit' else 2)
df['fit'] = df['fit'].apply(lambda x: x == 'fit')
df['review_date'] = df['review_date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
df['rating'] = df['rating'].apply(lambda x: rating_dict[x] if type(x) == str else x)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shli_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
punctuation = set(string.punctuation)
stopwordsSet = set(stopwords.words("english"))
def clean_text(text):
    text = ''.join([c for c in text.lower() if not c in punctuation])
    text = ' '.join(w for w in text.split() if w not in stopwordsSet)
    return text
df['review_text'] = df['review_text'].apply(lambda x: clean_text(x))

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146381 entries, 0 to 146380
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fit             146381 non-null  bool
#  1   user_id         146381 non-null  object
#  2   bust size       146381 non-null  object
#  3   item_id         146381 non-null  object
#  4   weight          146381 non-null  int64
#  5   rating          146381 non-null  int64
#  6   rented for      146381 non-null  object
#  7   review_text     146381 non-null  object
#  8   body type       146381 non-null  object
#  9   review_summary  146381 non-null  object
#  10  category        146381 non-null  object
#  11  height          146381 non-null  int64
#  12  size            146381 non-null  int64
#  13  age             146381 non-null  int64
#  14  review_date     146381 non-null  datetime64[ns]
#  15  fit_sml         146381 non-null  int64
# ...

# %%
df.describe()
# Out:
#               weight         rating         height           size  \
# count  146381.000000  146381.000000  146381.000000  146381.000000
# mean      137.209870       4.540992      65.263053      11.437919
# std        21.540182       0.718926       2.659230       7.826784
# min        50.000000       1.000000      54.000000       0.000000
# 25%       123.000000       4.000000      63.000000       4.000000
# 50%       135.000000       5.000000      65.000000       9.000000
# 75%       148.000000       5.000000      67.000000      16.000000
# max       300.000000       5.000000      78.000000      58.000000
#
#                  age        fit_sml
# count  146381.000000  146381.000000
# mean       34.089800       0.995928
# std         8.113217       0.513818
# min         0.000000       0.000000
# 25%        29.000000       1.000000
# 50%        32.000000       1.000000
# 75%        37.000000       1.000000
# max       117.000000       2.000000

# %%
df.nunique()
# Out:
# fit                    2
# user_id            77347
# bust size            101
# item_id             5736
# weight               186
# rating                 5
# rented for             9
# review_text       144375
# body type              7
# review_summary    119690
# category              68
# height                24
# size                  56
# age                   83
# review_date         2240
# fit_sml                3
# dtype: int64

# %%
for i in df.columns:
    if df[i].nunique() >= 20:
        continue
    print(f"{i}'s value counts:")
    print(df[i].value_counts())
# Out:
# fit's value counts:
# True     107733
# False     38648
# Name: fit, dtype: int64
# rating's value counts:
# 5    94291
# 4    40761
# 3     8341
# 2     2205
# 1      783
# Name: rating, dtype: int64
# rented for's value counts:
# wedding            42622
# formal affair      30496
# party              27198
# everyday           13263
# work               12124
# other              11510
# date                5929
# vacation            3238
# party: cocktail        1
# Name: rented for, dtype: int64
# body type's value counts:
# hourglass            43982
# athletic             37518
# petite               19358
# pear                 18051
# straight & narrow    12866
# full bust            10797
# apple                 3809
# Name: body type, dtype: int64
# fit_sml's value counts:
# 1    107733
# 0     19622
# 2     19026
# Name: fit_sml, dtype: int64

# %% [markdown]
# ### Heights

# %%
# overview of the whole distribution of height
plt.figure(figsize=(8, 6))
sns.histplot(data=df,x = 'height', bins=20)
plt.xlabel('height (inch)')
plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(15, 12))
axs = axs.flat
axs[-1].remove()
axs = axs[:-1]
plt.subplots_adjust(hspace=0.5)
fig.suptitle("Height Distribution Per Rating", fontsize=18, y=0.95)

for ax, gb in zip(axs, df.groupby('rating')):
    rate, dfs = gb
    sns.histplot(data = dfs,x = 'height', bins=20, ax = ax)
    ax.set_title(f'Height Distribution of Rating {int(rate)}')
    ax.set_xlabel("Height")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x="height", hue="fit", bins=20, stat="density").set(title='Histogram of Height on Fitness', xlabel = 'Height')
plt.show()

# %% [markdown]
# ### Weights

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x = 'weight', bins=30)
plt.xlabel('weight (lbs)')
plt.show()

# %%
# define subplot grid
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(15, 12))
axs = axs.flat
axs[-1].remove()
axs = axs[:-1]
plt.subplots_adjust(hspace=0.5)
fig.suptitle("Weight Distribution Per Rating", fontsize=18, y=0.95)

# loop through tickers and axes
for gb, ax in zip(df.groupby('rating'), axs.ravel()):
    rate, dfs = gb
    sns.histplot(data = dfs,x = 'weight', bins=20, ax = ax)
    ax.set_title(f'Weight Distribution of Rating {int(rate)}')
    ax.set_xlabel("")

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x="weight", hue="fit", bins=20, stat="density").set(title='Histogram of Weight on Fitness', xlabel = 'Weight')
plt.show()

# %% [markdown]
# ### Category data and standardize date

# %%
data = df['fit'].value_counts().tolist()
labels = ['fit', 'not fit']
colors = sns.color_palette('pastel')[0:2]
plt.figure(figsize=(8, 6))
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
data = df['rented for'].value_counts().tolist()
labels = ['wedding', 'formal affair', 'party', 'everyday', 'other', 'work', 'date', 'vacation', 'party']
colors = sns.color_palette('pastel')[0:9]
plt.figure(figsize=(8, 6))
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
df['body type'].value_counts()
# Out:
# hourglass            43982
# athletic             37518
# petite               19358
# pear                 18051
# straight & narrow    12866
# full bust            10797
# apple                 3809
# Name: body type, dtype: int64

# %%
data = df['body type'].value_counts().tolist()
labels = ['hourglass', 'athletic', 'pear', 'petite', 'full bust', 'straight & narrow', 'apple']
colors = sns.color_palette('pastel')[0:7]
plt.figure(figsize=(8, 6))
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x = 'rating', bins=5)
plt.xlabel('Rating distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x = 'size', bins=20)
plt.xlabel('Size distribution')
plt.show()

# %%
# drop users who are younger than 10 and older than 80
df = df[(df['age'] > 10) & (df['age'] < 80)]
df = df.reset_index(drop=True)

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x = 'age', bins=30)
plt.xlabel('Age distribution')
plt.show()

# %%
df_date = df["review_date"].apply(lambda x : pd.to_datetime(x))
min_date = min(df_date)
date_diff = (df_date - min_date).astype(str).apply(lambda x : x.split()[0]).astype(int)
std_date_diff = ((date_diff - np.mean(date_diff))/np.std(date_diff))
df['review_date'] = std_date_diff
df.head(5)
# Out:
#     fit user_id bust size  item_id  weight  rating     rented for  \
# 0  True  420272       34d  2260466     137       5       vacation
# 1  True  273551       34b   153475     132       5          other
# 2  True  909926       34c   126335     135       4  formal affair
# 3  True  151944       34b   616682     145       5        wedding
# 4  True  734848       32b   364092     138       4           date
#
#                                          review_text          body type  \
# 0  adorable romper belt zipper little hard naviga...          hourglass
# 1  rented dress photo shoot theme hollywood glam ...  straight & narrow
# 2  rented companys black tie awards banquet liked...               pear
# 3  always petite upper body extremely athletic im...           athletic
# 4  didnt actually wear fit perfectly fabric littl...           athletic
#
#                                      review_summary category  height  size  \
# ...

# %%
df['bust size'].unique()
# Out:
# array(['34d', '34b', '34c', '32b', '34d+', '36a', '36d', '32d+', '32c',
#        '30dd', '36b', '36c', '32d', '34a', '34dd', '32a', '34ddd/e',
#        '38d+', '38a', '38b', '38d', '36ddd/e', '38dd', '38f', '42dd',
#        '40dd', '32dd', '38c', '30ddd/e', '32ddd/e', '36dd', '36d+', '40d',
#        '28dd', '42c', '30d', '30b', '34aa', '32aa', '36f', '28c', '36aa',
#        '34g', '42ddd/e', '40c', '34f', '28g', '28aa', '36g', '28f',
#        '44ddd/e', '42d', '40ddd/e', '30c', '30aa', '44dd', '32i', '32g',
#        '30g', '30h', '30a', '34j', '38ddd/e', '32h', '28a', '32f', '44d',
#        '40h', '38g', '40g', '28b', '34h', '36j', '36h', '28ddd/e', '44f',
#        '34i', '30f', '36i', '30i', '28h', '42b', '42j', '40f', '38aa',
#        '38i', '48dd', '28d', '46ddd/e', '42g', '48d', '38h', '40b', '40j',
#        '32j', '38j', '44b', '44c', '44g', '42f', '44h'], dtype=object)

# %%
# Drop bust size
df.drop(columns=['bust size'])
# Out:
#          fit user_id  item_id  weight  rating     rented for  \
# 0       True  420272  2260466     137       5       vacation
# 1       True  273551   153475     132       5          other
# 2       True  909926   126335     135       4  formal affair
# 3       True  151944   616682     145       5        wedding
# 4       True  734848   364092     138       4           date
# ...      ...     ...      ...     ...     ...            ...
# 146265  True   66386  2252812     140       5           work
# 146266  True  118398   682043     100       5           work
# 146267  True   47002   683251     135       3       everyday
# 146268  True  961120   126335     165       5        wedding
# 146269  True  123612   127865     155       5        wedding
#
#                                               review_text          body type  \
# 0       adorable romper belt zipper little hard naviga...          hourglass
# ...

# %% [markdown]
# ### Clothes Category

# %%
most_common_cat = df['category'].value_counts()[:9].index.tolist()
cnt_cat = []
for i in most_common_cat:
    cnt_cat.append(len(df[df['category'] == i]))
most_common_cat.append('other')
cnt_cat.append(len(df) - sum(cnt_cat))

# %%
fig = plt.figure(figsize=(10, 20))
colors = sns.color_palette('pastel')[0:10]
explode = [0.01] * len(most_common_cat)
plt.pie(cnt_cat, labels = most_common_cat, colors=colors,autopct='%1.1f%%',startangle=90, pctdistance=0.5, explode = explode)
centre_circle = plt.Circle((0,0),0.50,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle) 
plt.tight_layout()
plt.legend()
plt.title("Percentage of Clothes Category among Purchases",fontsize=30)
plt.show()

# %% [markdown]
# ### Review

# %%
# review among all dataset
text = " ".join(d for d in df['review_text'])
wordcloud = WordCloud(width=400, height=330, max_words=150,colormap="Dark2").generate(text)
fig = plt.figure(figsize=(10, 20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# review for people who think the clothes fit small
text_small = " ".join(d for d in df[df['fit_sml'] == 0]['review_text'])
wordcloud = WordCloud(width=400, height=330, max_words=150,colormap="Dark2").generate(text_small)
fig = plt.figure(figsize=(10, 20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# review for people who think the clothes fit well
text_fit = " ".join(d for d in df[df['fit_sml'] == 1]['review_text'])
wordcloud = WordCloud(width=400, height=330, max_words=150,colormap="Dark2").generate(text_fit)
fig = plt.figure(figsize=(10, 20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# review for people who think the clothes fit large
text_large = " ".join(d for d in df[df['fit_sml'] == 2]['review_text'])
wordcloud = WordCloud(width=400, height=330, max_words=150,colormap="Dark2").generate(text_large)
fig = plt.figure(figsize=(10, 20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
len(df)
# Out:
# 146270

# %%
#Convert the data frame back to list of dict
data_renttherunway = df.to_dict('records')

# %%
len(data_renttherunway)
# Out:
# 146270

# %% [markdown]
# # Process `review_text` in `data_renttherunway`

# %%
# from nltk.stem.snowball import stopwords
# stopwordsSet = set(stopwords.words("english"))

# %%
# len(stopwordsSet)

# %%
# punctuation = set(string.punctuation)

# %%
# def clean_text(text):
#   text = ''.join([c for c in text.lower() if not c in punctuation])
#   text = ' '.join(w for w in text.split() if w not in stopwordsSet)
#   return text

# %%
# # Process the review_text for each entry
# for d in data_renttherunway:
#   d['review_text'] = clean_text(d['review_text'])

# %%
data_renttherunway[0]
# Out:
# {'fit': True,
#  'user_id': '420272',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': 137,
#  'rating': 5,
#  'rented for': 'vacation',
#  'review_text': 'adorable romper belt zipper little hard navigate full day wearbathroom use thats expected wish pockets absolutely perfect got million compliments',
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': 68,
#  'size': 14,
#  'age': 28,
#  'review_date': 0.07013649419996568,
#  'fit_sml': 1}

# %%
data_renttherunway = []
for index, row in df.iterrows():
    data_renttherunway.append(row.to_dict())

# %%
data_renttherunway_train = data_renttherunway[:len(data_renttherunway)//2]
data_renttherunway_valid = data_renttherunway[len(data_renttherunway)//2:]

# %%
print(len(data_renttherunway_valid))
print(len(data_renttherunway_train))
# Out:
# 73135
# 73135

# %% [markdown]
# ### Baseline model

# %%
#Baseline model, simply return the mean rating of each user

# %%
usersPerItem = defaultdict(set) # Maps an item to the users who rated it
itemsPerUser = defaultdict(set) # Maps a user to the items that they rated
reviewsPerUser = defaultdict(list)
reviewsPerItem = defaultdict(list)
ratingDict = {}

# %%
for d in data_renttherunway_train:
    user,item = d['user_id'], d['item_id']
    usersPerItem[d['item_id']].add(d['user_id'])
    itemsPerUser[d['user_id']].add(d['item_id'])
    reviewsPerUser[d['user_id']].append(d)
    reviewsPerItem[d['item_id']].append(d)
    ratingDict[(user,item)] = d['rating']

# %%
globalMean = 0
for d in data_renttherunway_train:
    globalMean+=int(d['rating'])
globalMean = globalMean/len(data_renttherunway_train)

# %%
globalMean
# Out:
# 4.54331031653791

# %%
ypred = []
for d in data_renttherunway_valid:
    reviews_this_user = reviewsPerUser[d['user_id']]
    userMean = 0
    userLen = len(reviews_this_user)
    if userLen == 0:
        ypred.append(globalMean)
    else:
        for r in reviews_this_user:
            userMean+=r['rating']
        ypred.append(userMean/userLen)

# %%
ytrain = []
for d in data_renttherunway_train:
    ytrain.append(int(d['rating']))

yvalid = []
for d in data_renttherunway_valid:
    yvalid.append(int(d['rating']))

# %%
print(mean_squared_error(yvalid, ypred))
print(mean_absolute_error(yvalid, ypred))
print(r2_score(yvalid, ypred))
# Out:
# 0.6241660980034783
# 0.5807435549009965
# -0.1993488588185004

# %% [markdown]
# ### LinearRegression model

# %%
#Improved model, use linear regression to predict rating

# %%
df.head(3)
# Out:
#     fit user_id bust size  item_id  weight  rating     rented for  \
# 0  True  420272       34d  2260466     137       5       vacation
# 1  True  273551       34b   153475     132       5          other
# 2  True  909926       34c   126335     135       4  formal affair
#
#                                          review_text          body type  \
# 0  adorable romper belt zipper little hard naviga...          hourglass
# 1  rented dress photo shoot theme hollywood glam ...  straight & narrow
# 2  rented companys black tie awards banquet liked...               pear
#
#                                      review_summary category  height  size  \
# 0                              So many compliments!   romper      68    14
# 1                           I felt so glamourous!!!     gown      66    12
# 2  Dress arrived on time and in perfect condition.     dress      65     8
#
#    age  review_date  fit_sml
# 0   28     0.070136        1
# 1   36    -2.034953        1
# ...

# %%
feat_h = df['height'].to_numpy()
feat_w = df['weight'].to_numpy()
feat_a = df['age'].to_numpy()
feat_s = df['size'].to_numpy()
feat_f = df['fit'].to_numpy()
bias = [1] * len(df)
X = []
X = np.column_stack((feat_h, feat_w, feat_a, feat_s, feat_f, bias))
# y = df['rating'].to_numpy()

# %%
X
# Out:
# array([[ 68, 137,  28,  14,   1,   1],
#        [ 66, 132,  36,  12,   1,   1],
#        [ 65, 135,  34,   8,   1,   1],
#        ...,
#        [ 68, 135,  31,   8,   1,   1],
#        [ 66, 165,  31,  16,   1,   1],
#        [ 66, 155,  30,  16,   1,   1]])

# %%
Xtrain = X[:len(X)//2]
Xvalid = X[len(X)//2:]

# %%
len(Xtrain), len(Xvalid), len(ytrain), len(yvalid)
# Out:
# (73135, 73135, 73135, 73135)

# %%
# Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
clf = LinearRegression(fit_intercept=False)
clf.fit(Xtrain, ytrain)
# Out:
# LinearRegression(fit_intercept=False)

# %%
ypred = clf.predict(Xvalid)
# accuracy_score(ypred, ytest)
print(mean_squared_error(yvalid, ypred))
print(mean_absolute_error(yvalid, ypred))
print(r2_score(yvalid, ypred))
# Out:
# 0.48507690330652925
# 0.5513457168779813
# 0.06791408203549076

# %% [markdown]
# ### Latent factor model (Tensorflow)

# %%
userIDs = {}
itemIDs = {}
interactions = []

for d in data_renttherunway:
    u = d['user_id']
    i = d['item_id']
    r = int(d['rating'])
    if not u in userIDs: userIDs[u] = len(userIDs)
    if not i in itemIDs: itemIDs[i] = len(itemIDs)
    interactions.append((u,i,r))

# %%
X = interactions
y = [i[2] for i in interactions]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
# interactionsTrain = interactions[:len(interactions)//2]
# interactionsValid = interactions[len(interactions)//2:]

# %%
itemsPerUser = defaultdict(list)
usersPerItem = defaultdict(list)
for u,i,r in Xtrain:
    itemsPerUser[u].append(i)
    usersPerItem[i].append(u)

# %%
mu = sum([r for _,_,r in Xtrain]) / len(Xtrain)

# %%
optimizer = tf.keras.optimizers.Adam(0.1)

# %%
class LatentFactorModel(tf.keras.Model):
    def __init__(self, mu, K, lamb):
        super(LatentFactorModel, self).__init__()
        # Initialize to average
        self.alpha = tf.Variable(mu)
        # Initialize to small random values
        self.betaU = tf.Variable(tf.random.normal([len(userIDs)],stddev=0.001))
        self.betaI = tf.Variable(tf.random.normal([len(itemIDs)],stddev=0.001))
        self.gammaU = tf.Variable(tf.random.normal([len(userIDs),K],stddev=0.001))
        self.gammaI = tf.Variable(tf.random.normal([len(itemIDs),K],stddev=0.001))
        self.lamb = lamb

    # Prediction for a single instance (useful for evaluation)
    def predict(self, u, i):
        p = self.alpha + self.betaU[u] + self.betaI[i] +\
            tf.tensordot(self.gammaU[u], self.gammaI[i], 1)
        return p

    # Regularizer
    def reg(self):
        return self.lamb * (tf.reduce_sum(self.betaU**2) +\
                            tf.reduce_sum(self.betaI**2) +\
                            tf.reduce_sum(self.gammaU**2) +\
                            tf.reduce_sum(self.gammaI**2))
    
    # Prediction for a sample of instances
    def predictSample(self, sampleU, sampleI):
        u = tf.convert_to_tensor(sampleU, dtype=tf.int32)
        i = tf.convert_to_tensor(sampleI, dtype=tf.int32)
        beta_u = tf.nn.embedding_lookup(self.betaU, u)
        beta_i = tf.nn.embedding_lookup(self.betaI, i)
        gamma_u = tf.nn.embedding_lookup(self.gammaU, u)
        gamma_i = tf.nn.embedding_lookup(self.gammaI, i)
        pred = self.alpha + beta_u + beta_i +\
               tf.reduce_sum(tf.multiply(gamma_u, gamma_i), 1)
        return pred
    
    # Loss
    def call(self, sampleU, sampleI, sampleR):
        pred = self.predictSample(sampleU, sampleI)
        r = tf.convert_to_tensor(sampleR, dtype=tf.float32)
        return tf.nn.l2_loss(pred - r) / len(sampleR)

# %%
modelLFM = LatentFactorModel(mu, 5, 0.00001)

# %%
def trainingStep(model, interactions):
    Nsamples = 50000
    with tf.GradientTape() as tape:
        sampleU, sampleI, sampleR = [], [], []
        for _ in range(Nsamples):
            u,i,r = random.choice(interactions)
            sampleU.append(userIDs[u])
            sampleI.append(itemIDs[i])
            sampleR.append(r)

        loss = model(sampleU,sampleI,sampleR)
        loss += model.reg()
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients((grad, var) for
                              (grad, var) in zip(gradients, model.trainable_variables)
                              if grad is not None)
    return loss.numpy()

# %%
# Try pipline find the parameters
ls = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]

for p in ls: 
    mu = sum([r for _,_,r in Xtrain]) / len(Xtrain)
    optimizer = tf.keras.optimizers.Adam(0.1)
    modelLFM = LatentFactorModel(mu, 5, p)
    for i in range(100):
        obj = trainingStep(modelLFM, Xtrain)
        if (i % 10 == 9): print("iteration " + str(i+1) + ", objective = " + str(obj))
    
    ypred = []
    yvalid = ytest

    for d in Xtest:
        u, i, r = d[0], d[1], d[2]
        ypred.append(modelLFM.predict(userIDs[u], itemIDs[i]).numpy())

    print(mean_squared_error(yvalid, ypred))
# Out:
# iteration 10, objective = 1328.9231
# iteration 20, objective = 57.801758
# iteration 30, objective = 47.230858
# iteration 40, objective = 55.02793
# iteration 50, objective = 24.556696
# iteration 60, objective = 9.01184
# iteration 70, objective = 2.7362196
# iteration 80, objective = 0.5380825
# iteration 90, objective = 0.3293547
# iteration 100, objective = 0.4097426
# 0.5104706651271116
# iteration 10, objective = 128.57974
# iteration 20, objective = 11.917561
# iteration 30, objective = 2.8367615
# iteration 40, objective = 3.8275712
# iteration 50, objective = 1.9749265
# iteration 60, objective = 0.83738387
# iteration 70, objective = 0.38562304
# iteration 80, objective = 0.28158626
# iteration 90, objective = 0.28568834
# iteration 100, objective = 0.27533948
# 0.510210937827006
# iteration 10, objective = 8.608785
# iteration 20, objective = 2.6111405
# iteration 30, objective = 0.79730546
# iteration 40, objective = 0.42156482
# iteration 50, objective = 0.32695928
# ...

# %% [markdown]
# ### Jaccord model

# %%
usersPerItem = defaultdict(set) # Maps an item to the users who rated it
itemsPerUser = defaultdict(set) # Maps a user to the items that they rated
reviewsPerUser = defaultdict(list)
reviewsPerItem = defaultdict(list)
ratingDict = {} # To retrieve a rating for a specific user/item pair

for d in data_renttherunway_train:
    user,item = d['user_id'], d['item_id']
    usersPerItem[d['item_id']].add(d['user_id'])
    itemsPerUser[d['user_id']].add(d['item_id'])
    reviewsPerUser[d['user_id']].append(d)
    reviewsPerItem[d['item_id']].append(d)
    ratingDict[(user,item)] = d['rating']

# %%
def Jaccard(s1, s2):
    numer = len(s1.intersection(s2))
    denom = len(s1.union(s2))
    if denom == 0:
        return 0
    return numer / denom

# %%
userAverages = {}
itemAverages = {}

for u in itemsPerUser:
    rs = [ratingDict[(u,i)] for i in itemsPerUser[u]]
    userAverages[u] = sum(rs) / len(rs)
    
for i in usersPerItem:
    rs = [ratingDict[(u,i)] for u in usersPerItem[i]]
    itemAverages[i] = sum(rs) / len(rs)

# %%
def predictRating(user,item):
    ratings = []
    similarities = []
    for d in reviewsPerUser[user]:
        i2 = d['item_id']
        if i2 == item: continue
        ratings.append(d['rating'] - itemAverages[i2])
        similarities.append(Jaccard(usersPerItem[item],usersPerItem[i2]))
    if (sum(similarities) > 0):
        weightedRatings = [(x*y) for x,y in zip(ratings,similarities)]
        return itemAverages[item] + sum(weightedRatings) / sum(similarities)
    else:
        # User hasn't rated any similar items
        return sum([d['rating'] for d in data_renttherunway_train]) / len(data_renttherunway_train)

# %%
simPredictions = [predictRating(d['user_id'], d['item_id']) for d 
                  in data_renttherunway_valid]

# %%
labels = [d['rating'] for d in data_renttherunway_valid]

# %%
print(mean_squared_error(labels, simPredictions))
print(mean_absolute_error(yvalid, ypred))
print(r2_score(yvalid, ypred))
# Out:
# 0.5489802878228296
# 0.558189762165943
# -0.020005933335596193

# %% [markdown]
# ### Linear Regression model with text

# %%
words_count = defaultdict(int)
for d in df['review_text'].tolist():
    for w in set(d.split()):
        words_count[w] += 1
counts = sorted([(v,k) for k, v in words_count.items()], reverse=True)
first_1000_words = [i[1] for i in counts[:1000]]

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(first_1000_words)
# Out:
# <1000x989 sparse matrix of type '<class 'numpy.int64'>'
# 	with 989 stored elements in Compressed Sparse Row format>

# %%
def feature(data):
    feat = vectorizer.transform([data['review_text']]).toarray()[0]
    return [1, data['height'], data['weight'], data['age'], data['size'], data['fit']] + list(feat)

# %%
X = [feature(i) for i in data_renttherunway_train]
y = [i['rating'] for i in data_renttherunway_train]
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=42)
clf = LinearRegression(fit_intercept=False)
clf.fit(Xtrain, ytrain)
ypred = clf.predict(Xtest)
mse = mean_squared_error(ytest, ypred)
mae = mean_absolute_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print(mse)
print(mae)
print(r2)
# best_mse = float('inf')
# best_model = 0
# for alpha_n in np.arange(0.0, 1.0, 0.1):
#     clf = LinearRegression(fit_intercept=False)
#     clf.fit(Xtrain, ytrain)
#     ypred = clf.predict(Xtest)
#     mse = mean_squared_error(ytest, ypred)
#     print(mean_squared_error(ytest, ypred))
#     if mse < best_mse:
#         best_model = clf
#         best_mse = mse
# print(best_mse, best_model.coef_)
# Out:
# 0.38014456635705707
# 0.4680263718315656
# 0.25926881846488226

# %% [markdown]
# ### Linear Regression Model With Text and Max Similiarity

# %%
def maxSimiliarity(data):
    item = data['item_id']
    maxSim = -float('inf')
    for i2 in usersPerItem:
        if item == i2: continue
        sim = Jaccard(usersPerItem[item], usersPerItem[i2])
        maxSim = max(sim, maxSim)
    return maxSim

# %%
def feature(data):
    feat = vectorizer.transform([data['review_text']]).toarray()[0]
    return [1, data['height'], data['weight'], data['age'], data['size'], data['fit'], maxSimiliarity(data)] + list(feat)

# %%
X = [feature(i) for i in data_renttherunway_train]
y = [i['rating'] for i in data_renttherunway_train]
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=42)
clf = LinearRegression(fit_intercept=False)
clf.fit(Xtrain, ytrain)
ypred = clf.predict(Xtest)
mse = mean_squared_error(ytest, ypred)
mae = mean_absolute_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print(mse)
print(mae)
print(r2)
# Out:
# 0.38015381790341213
# 0.4680070096571051
# 0.2592507913523858
