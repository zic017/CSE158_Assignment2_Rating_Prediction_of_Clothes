# %%
import gzip
import json
import numpy as np
import seaborn as sns
sns.set()
sns.set_context('talk')

# %%
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        l = str(json.loads(l))
        yield eval(l)

# %%
data_modcloth = []
for l in parse("modcloth_final_data.json.gz"):
    
    data_modcloth.append(l)

# %%
data_renttherunway = []
for l in parse("renttherunway_final_data.json.gz"):
    
    data_renttherunway.append(l)

# %%
data_renttherunway[0]
# Out:
# {'fit': 'fit',
#  'user_id': '420272',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': '137lbs',
#  'rating': '10',
#  'rented for': 'vacation',
#  'review_text': "An adorable romper! Belt and zipper were a little hard to navigate in a full day of wear/bathroom use, but that's to be expected. Wish it had pockets, but other than that-- absolutely perfect! I got a million compliments.",
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': '5\' 8"',
#  'size': 14,
#  'age': '28',
#  'review_date': 'April 20, 2016'}

# %%
len(data_renttherunway)
# Out:
# 192544

# %%
def standardize_height(str_in):

    if str_in == None:
        return
    if '\'' in str_in:
        str_in = str_in.replace('\'', '')
    if '"' in str_in:
        str_in = str_in.replace('"', '')

    foot,inch = str_in.strip().split(' ')
    output = int(foot) * 12 + int(inch)

    return output

# %%
for d in data_renttherunway:
    d['height'] = standardize_height(d.get('height'))

# %%
heights = [d['height'] for d in data_renttherunway]

# %%
heights
# Out:
# [68,
#  66,
#  64,
#  65,
#  69,
#  68,
#  63,
#  63,
#  66,
#  63,
#  63,
#  66,
#  66,
#  62,
#  65,
#  67,
#  68,
#  65,
#  63,
#  66,
#  65,
#  66,
#  65,
#  66,
#  68,
#  66,
#  66,
#  63,
#  69,
#  61,
#  63,
#  65,
#  63,
#  63,
#  70,
#  68,
#  63,
#  66,
#  65,
#  66,
#  61,
#  68,
#  64,
#  64,
#  62,
#  65,
#  68,
#  68,
#  66,
#  64,
#  67,
#  67,
#  67,
#  62,
#  61,
#  67,
#  64,
#  69,
#  67,
#  68,
#  62,
#  66,
#  64,
#  64,
#  65,
#  66,
#  62,
#  67,
#  65,
#  63,
#  63,
#  66,
#  68,
#  68,
#  65,
#  64,
#  65,
#  66,
#  69,
#  65,
#  62,
#  66,
#  69,
#  65,
#  64,
#  66,
#  63,
#  63,
#  64,
#  64,
#  64,
#  68,
#  62,
#  65,
#  66,
#  66,
#  69,
#  62,
#  65,
#  66,
#  64,
#  62,
#  62,
#  67,
#  69,
#  61,
#  64,
#  65,
#  62,
#  62,
#  66,
#  64,
#  68,
#  66,
#  65,
#  62,
#  61,
#  67,
#  64,
#  70,
#  68,
#  61,
#  63,
#  66,
#  66,
#  72,
#  64,
#  68,
#  66,
#  58,
#  64,
#  67,
#  69,
#  68,
#  66,
#  62,
#  68,
#  67,
#  67,
#  67,
#  69,
#  67,
#  66,
#  61,
#  63,
#  66,
#  66,
#  68,
#  70,
#  64,
#  67,
#  73,
#  66,
#  64,
#  67,
#  63,
#  68,
#  69,
#  68,
#  67,
#  67,
#  69,
#  68,
#  71,
#  66,
#  67,
#  66,
#  66,
#  64,
#  61,
#  64,
#  62,
#  66,
#  68,
#  69,
#  64,
#  67,
#  67,
#  69,
#  67,
#  64,
#  63,
#  68,
#  71,
#  63,
#  67,
#  63,
#  64,
#  64,
#  68,
#  64,
#  62,
#  63,
#  65,
#  60,
#  62,
#  65,
#  62,
#  61,
#  67,
#  64,
#  63,
#  70,
#  62,
#  64,
#  None,
#  66,
#  60,
#  62,
#  65,
#  68,
#  61,
#  68,
#  62,
#  66,
#  62,
#  69,
#  62,
#  68,
#  63,
#  66,
#  66,
#  64,
#  64,
#  68,
#  63,
#  69,
#  62,
#  68,
#  71,
#  63,
#  64,
#  68,
#  68,
#  62,
#  69,
#  60,
#  68,
#  66,
#  64,
#  64,
#  66,
#  63,
#  70,
#  67,
#  68,
#  66,
#  65,
#  65,
#  67,
#  63,
#  64,
#  66,
#  67,
#  64,
#  68,
#  67,
#  60,
#  66,
#  69,
#  64,
#  60,
#  66,
#  62,
#  66,
#  63,
#  67,
#  66,
#  66,
#  63,
#  60,
#  62,
#  63,
#  69,
#  63,
#  64,
#  65,
#  64,
#  67,
#  64,
#  61,
#  67,
#  62,
#  66,
#  67,
#  67,
#  70,
#  68,
#  65,
#  66,
#  68,
#  64,
#  65,
#  64,
#  61,
#  67,
#  69,
#  68,
#  64,
#  64,
#  61,
#  64,
#  69,
#  66,
#  69,
#  66,
#  64,
#  69,
#  66,
#  66,
#  63,
#  66,
#  63,
#  60,
#  64,
#  62,
#  69,
#  70,
#  63,
#  63,
#  63,
#  66,
#  62,
#  64,
#  66,
#  65,
#  62,
#  64,
#  69,
#  59,
#  65,
#  63,
#  63,
#  65,
#  66,
#  65,
#  67,
#  66,
#  62,
#  65,
#  68,
#  65,
#  68,
#  67,
#  64,
#  65,
#  68,
#  66,
#  72,
#  71,
#  62,
#  67,
#  65,
#  69,
#  60,
#  62,
#  67,
#  62,
#  63,
#  68,
#  61,
#  69,
#  67,
#  64,
#  67,
#  64,
#  68,
#  66,
#  64,
#  69,
#  64,
#  62,
#  70,
#  64,
#  65,
#  68,
#  65,
#  67,
#  68,
#  66,
#  66,
#  64,
#  65,
#  67,
#  70,
#  66,
#  67,
#  64,
#  62,
#  69,
#  67,
#  66,
#  68,
#  69,
#  70,
#  65,
#  63,
#  66,
#  63,
#  67,
#  64,
#  64,
#  64,
#  64,
#  69,
#  66,
#  67,
#  69,
#  66,
#  61,
#  71,
#  66,
#  63,
#  64,
#  64,
#  64,
#  63,
#  66,
#  69,
#  69,
#  66,
#  67,
#  65,
#  63,
#  62,
#  70,
#  65,
#  63,
#  67,
#  61,
#  66,
#  69,
#  70,
#  64,
#  70,
#  65,
#  70,
#  69,
#  65,
#  62,
#  60,
#  67,
#  68,
#  66,
#  63,
#  64,
#  65,
#  72,
#  64,
#  64,
#  68,
#  67,
#  64,
#  67,
#  62,
#  63,
#  64,
#  66,
#  66,
#  65,
#  66,
#  66,
#  65,
#  62,
#  70,
#  61,
#  71,
#  65,
#  64,
#  67,
#  67,
#  65,
#  66,
#  71,
#  67,
#  67,
#  64,
#  64,
#  66,
#  67,
#  67,
#  63,
#  65,
#  64,
#  66,
#  65,
#  63,
#  64,
#  67,
#  69,
#  63,
#  63,
#  64,
#  67,
#  71,
#  68,
#  64,
#  65,
#  65,
#  64,
#  63,
#  61,
#  66,
#  68,
#  67,
#  67,
#  63,
#  61,
#  69,
#  68,
#  66,
#  64,
#  68,
#  64,
#  65,
#  65,
#  63,
#  60,
#  68,
#  66,
#  64,
#  65,
#  66,
#  69,
#  None,
#  67,
#  68,
#  64,
#  68,
#  70,
#  69,
#  69,
#  66,
#  67,
#  68,
#  60,
#  68,
#  66,
#  63,
#  71,
#  69,
#  65,
#  63,
#  None,
#  64,
#  68,
#  71,
#  67,
#  65,
#  66,
#  60,
#  63,
#  63,
#  64,
#  65,
#  67,
#  70,
#  70,
#  64,
#  64,
#  62,
#  62,
#  66,
#  65,
#  67,
#  64,
#  66,
#  65,
#  67,
#  61,
#  61,
#  63,
#  69,
#  60,
#  64,
#  67,
#  64,
#  68,
#  61,
#  67,
#  67,
#  62,
#  64,
#  65,
#  64,
#  66,
#  63,
#  65,
#  68,
#  62,
#  63,
#  66,
#  66,
#  63,
#  63,
#  64,
#  61,
#  67,
#  64,
#  64,
#  66,
#  64,
#  60,
#  62,
#  63,
#  67,
#  63,
#  67,
#  67,
#  66,
#  63,
#  62,
#  69,
#  64,
#  66,
#  68,
#  66,
#  62,
#  62,
#  65,
#  64,
#  68,
#  56,
#  68,
#  66,
#  65,
#  66,
#  66,
#  64,
#  61,
#  64,
#  66,
#  62,
#  67,
#  61,
#  68,
#  64,
#  60,
#  65,
#  64,
#  68,
#  67,
#  64,
#  68,
#  65,
#  64,
#  70,
#  62,
#  62,
#  63,
#  65,
#  68,
#  68,
#  62,
#  72,
#  68,
#  65,
#  66,
#  65,
#  63,
#  61,
#  65,
#  67,
#  65,
#  63,
#  62,
#  69,
#  69,
#  70,
#  66,
#  64,
#  64,
#  60,
#  67,
#  64,
#  64,
#  62,
#  64,
#  68,
#  64,
#  60,
#  67,
#  70,
#  66,
#  70,
#  69,
#  65,
#  68,
#  65,
#  65,
#  61,
#  68,
#  67,
#  62,
#  66,
#  66,
#  63,
#  72,
#  61,
#  62,
#  63,
#  64,
#  71,
#  66,
#  66,
#  66,
#  66,
#  65,
#  68,
#  66,
#  67,
#  66,
#  67,
#  72,
#  67,
#  66,
#  67,
#  62,
#  61,
#  70,
#  66,
#  66,
#  70,
#  68,
#  70,
#  66,
#  62,
#  66,
#  63,
#  62,
#  69,
#  60,
#  70,
#  63,
#  62,
#  66,
#  62,
#  64,
#  68,
#  62,
#  61,
#  64,
#  61,
#  64,
#  67,
#  67,
#  67,
#  63,
#  60,
#  63,
#  65,
#  67,
#  65,
#  64,
#  63,
#  66,
#  69,
#  65,
#  66,
#  64,
#  63,
#  66,
#  63,
#  62,
#  66,
#  64,
#  63,
#  65,
#  67,
#  66,
#  68,
#  65,
#  74,
#  71,
#  62,
#  65,
#  65,
#  67,
#  64,
#  64,
#  68,
#  73,
#  68,
#  69,
#  63,
#  68,
#  62,
#  64,
#  67,
#  67,
#  64,
#  65,
#  66,
#  64,
#  67,
#  66,
#  67,
#  64,
#  66,
#  62,
#  63,
#  64,
#  66,
#  66,
#  68,
#  70,
#  63,
#  63,
#  66,
#  62,
#  63,
#  66,
#  69,
#  64,
#  61,
#  64,
#  65,
#  65,
#  67,
#  64,
#  62,
#  64,
#  64,
#  66,
#  68,
#  66,
#  68,
#  62,
#  68,
#  64,
#  62,
#  63,
#  66,
#  70,
#  60,
#  64,
#  67,
#  65,
#  67,
#  71,
#  None,
#  65,
#  66,
#  64,
#  62,
#  62,
#  66,
#  67,
#  67,
#  67,
#  64,
#  63,
#  69,
#  64,
#  61,
#  69,
#  66,
#  65,
#  67,
#  61,
#  67,
#  68,
#  65,
#  67,
#  64,
#  67,
#  69,
#  66,
#  62,
#  66,
#  64,
#  65,
#  69,
#  66,
#  64,
#  62,
#  65,
#  64,
#  62,
#  66,
#  65,
#  66,
#  64,
#  65,
#  62,
#  69,
#  64,
#  63,
#  63,
#  63,
#  67,
#  68,
#  64,
#  66,
#  60,
#  64,
#  64,
#  62,
#  68,
#  63,
#  66,
#  67,
#  61,
#  67,
#  64,
#  65,
#  66,
#  67,
#  66,
#  66,
#  59,
#  65,
#  66,
#  65,
#  66,
#  61,
#  64,
#  63,
#  68,
#  68,
#  62,
#  64,
#  71,
#  65,
#  None,
#  67,
#  65,
#  65,
#  67,
#  68,
#  64,
#  65,
#  67,
#  67,
#  65,
#  67,
#  64,
#  65,
#  69,
#  65,
#  61,
#  64,
#  64,
#  64,
#  66,
#  65,
#  61,
#  62,
#  71,
#  68,
#  67,
#  66,
#  63,
#  67,
#  65,
#  62,
#  67,
#  65,
#  63,
#  61,
#  63,
#  68,
#  60,
#  70,
#  64,
#  67,
#  69,
#  65,
#  65,
#  64,
#  65,
#  68,
#  69,
#  68,
#  66,
#  69,
#  66,
#  64,
#  63,
#  64,
#  68,
#  65,
#  63,
#  67,
#  63,
#  66,
#  66,
#  65,
#  68,
#  73,
#  61,
#  61,
#  64,
#  63,
#  69,
#  68,
#  61,
#  64,
#  66,
#  64,
#  ...]

# %%
len(heights)
# Out:
# 192544

# %%
# if (heights)
# np.mean(heights)

# %%
sns.histplot(data=heights, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>
